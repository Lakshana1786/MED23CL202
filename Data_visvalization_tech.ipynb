# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshana1786/MED23CL202/blob/main/Data_visvalization_tech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt
data={
    "student":["rutu","mahi","Jaddu","pathirana"],
    "scores":[89073,45338,48794,48795],
}
df = pd.DataFrame(data)

sns.barplot(x="student",y="scores",data = df)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde

fees=[48000,43200,45600,38400,48000]

density = gaussian_kde(fees)
xs = np.linspace(min(fees),max(fees),200)
ys=density(xs)

plt.plot(xs,density(xs))
plt.show()

# %%
import matplotlib.pyplot as plt
fees=[48000,43200,45600,38400,48000]
plt.hist(fees)
plt.show()

# %%
import matplotlib.pyplot as plt
fees=[48000,43200,45600,38400,48000]
plt.boxplot(fees)
plt.show()
